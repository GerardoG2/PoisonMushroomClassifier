# %% [markdown]
# mushrooms

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
def load_and_process_data(file_path='../Data/raw_data.csv', header=True):
    """
    Load and process mushroom data from CSV file.
    
    Parameters:
    file_path (str): Path to the CSV file
    header (bool): Whether the file has a header row
    
    Returns:
    pandas.DataFrame: Processed mushroom data
    """
    # Read CSV with semicolon separator (not comma)
    df = pd.read_csv(file_path, sep=';')
    
    # Display basic info about the dataset
    print(f"Dataset shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print(f"Missing values per column:")
    print(df.isnull().sum())
    
    return df

# %%
df = load_and_process_data()
df
# Out:
# Dataset shape: (61069, 21)
# Columns: ['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color', 'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color', 'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color', 'habitat', 'season']
# Missing values per column:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51538
# stem-surface            38124
# stem-color                  0
# veil-type               57892
# veil-color              53656
# has-ring                    0
# ring-type                2471
# spore-print-color       54715
# habitat                     0
# season                      0
# dtype: int64
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# 2                        f               e          NaN          w
# 3                        f               e          NaN          w
# 4                        f               e          NaN          w
# ...                    ...             ...          ...        ...
# 61064                    f               f            f          f
# 61065                    f               f            f          f
# 61066                    f               f            f          f
# 61067                    f               f            f          f
# 61068                    f               f            f          f
#
#        stem-height  stem-width stem-root stem-surface stem-color veil-type  \
# 0            16.95       17.09         s            y          w         u
# 1            17.99       18.19         s            y          w         u
# 2            17.80       17.74         s            y          w         u
# 3            15.77       15.98         s            y          w         u
# 4            16.53       17.20         s            y          w         u
# ...            ...         ...       ...          ...        ...       ...
# 61064         3.93        6.22       NaN          NaN          y       NaN
# 61065         3.18        5.43       NaN          NaN          y       NaN
# 61066         3.86        6.37       NaN          NaN          y       NaN
# 61067         3.56        5.44       NaN          NaN          y       NaN
# 61068         3.25        5.45       NaN          NaN          y       NaN
#
#       veil-color has-ring ring-type spore-print-color habitat season
# 0              w        t         g               NaN       d      w
# 1              w        t         g               NaN       d      u
# 2              w        t         g               NaN       d      w
# 3              w        t         p               NaN       d      w
# 4              w        t         p               NaN       d      w
# ...          ...      ...       ...               ...     ...    ...
# 61064        NaN        f         f               NaN       d      a
# 61065        NaN        f         f               NaN       d      a
# 61066        NaN        f         f               NaN       d      u
# 61067        NaN        f         f               NaN       d      u
# 61068        NaN        f         f               NaN       d      u
#
# [61069 rows x 21 columns]

# %%
def display_class_distribution(df):
    """
    Display the class distribution of the mushroom dataset.
    
    Parameters:
    df (pandas.DataFrame): The mushroom dataset
    
    Returns:
    None: Prints the distribution and percentages
    """
    print("Class Distribution:")
    print("=" * 30)
    
    # Count values in the 'class' column
    class_counts = df['class'].value_counts()
    print(f"Total samples: {len(df)}")
    print()
    
    for class_label, count in class_counts.items():
        percentage = (count / len(df)) * 100
        class_name = "Poisonous" if class_label == 'p' else "Edible"
        print(f"{class_name} ({class_label}): {count:,} samples ({percentage:.2f}%)")
    
    print()
    
    # Additional statistics
    print("Class Balance:")
    ratio = class_counts.max() / class_counts.min()
    print(f"Imbalance ratio: {ratio:.2f}:1")
    
    return class_counts

# %%
# Display class distribution
class_dist = display_class_distribution(df)
# Out:
# Class Distribution:
# ==============================
# Total samples: 61069
#
# Poisonous (p): 33,888 samples (55.49%)
# Edible (e): 27,181 samples (44.51%)
#
# Class Balance:
# Imbalance ratio: 1.25:1

# %% [markdown]
# Drop Columns With over 50% missing data

# %%
columns_to_drop = ['stem-root','veil-type', 'veil-color',  'stem-surface', 'spore-print-color']
df = df.drop(columns=columns_to_drop)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap-diameter          61069 non-null  float64
#  2   cap-shape             61069 non-null  object
#  3   cap-surface           46949 non-null  object
#  4   cap-color             61069 non-null  object
#  5   does-bruise-or-bleed  61069 non-null  object
#  6   gill-attachment       51185 non-null  object
#  7   gill-spacing          36006 non-null  object
#  8   gill-color            61069 non-null  object
#  9   stem-height           61069 non-null  float64
#  10  stem-width            61069 non-null  float64
#  11  stem-color            61069 non-null  object
#  12  has-ring              61069 non-null  object
#  13  ring-type             58598 non-null  object
#  14  habitat               61069 non-null  object
#  15  season                61069 non-null  object
# dtypes: float64(3), object(13)
# memory usage: 7.5+ MB

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-color                  0
# has-ring                    0
# ring-type                2471
# habitat                     0
# season                      0
# dtype: int64

# %%
# get summary stats for numeric columns
df.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %%
# Standardize numeric columns
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_cols = ['cap-diameter', 'stem-height', 'stem-width']
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
df.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  6.106900e+04  6.106900e+04  6.106900e+04
# mean   5.212516e-17  2.233935e-16 -1.154200e-16
# std    1.000008e+00  1.000008e+00  1.000008e+00
# min   -1.206855e+00 -1.952985e+00 -1.210598e+00
# 25%   -6.180393e-01 -5.761259e-01 -6.914605e-01
# 50%   -1.659805e-01 -1.874007e-01 -1.952406e-01
# 75%    3.430605e-01  3.437583e-01  4.404789e-01
# max    1.056187e+01  8.112329e+00  9.143259e+00

# %%
# impute missing values for categorical columns using KNN
def knn_impute_categorical(df, target):
    from sklearn.compose import ColumnTransformer
    from sklearn.preprocessing import OneHotEncoder, StandardScaler
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.pipeline import Pipeline

    target = target

    mask = df[target].notna()  # rows where target is not null

    # build train_columns based on columns without nulls 
    _X_train_tmp = df.loc[mask].drop(columns=[target])
    train_columns = _X_train_tmp.columns[_X_train_tmp.isnull().sum() == 0].tolist()

    # training data where cap surface is not null
    X_train = df.loc[mask, train_columns]
    y_train = df.loc[mask, target]

    # predict on rows where cap surface is null
    X_missing = df.loc[~mask, train_columns]

    # define numeric and categorical columns
    num_cols = ['cap-diameter','stem-height','stem-width']
    cat_cols = [c for c in train_columns if c not in num_cols + [target]]

    # create preprocessor
    pre = ColumnTransformer([
        ("num", StandardScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ])

    # classifier pipeline
    clf = Pipeline([
        ("pre", pre),
        ("knn", KNeighborsClassifier(n_neighbors=5, weights="distance"))
    ])

    # fit classifier and predict missing values
    clf.fit(X_train, y_train)
    df.loc[~mask, target] = clf.predict(X_missing)  # fill in missing cap-surface values

    return df

# %%
# impute missing values iteratively using knn for categorical columns with missing values
# categorical columns with missing values
categorical_cols_with_nans = ['cap-surface', 'gill-attachment', 'gill-spacing', 'ring-type']
for col in categorical_cols_with_nans:
    df = knn_impute_categorical(df, col)

# %%
df.isnull().sum()
# Out:
# class                   0
# cap-diameter            0
# cap-shape               0
# cap-surface             0
# cap-color               0
# does-bruise-or-bleed    0
# gill-attachment         0
# gill-spacing            0
# gill-color              0
# stem-height             0
# stem-width              0
# stem-color              0
# has-ring                0
# ring-type               0
# habitat                 0
# season                  0
# dtype: int64

# %% [markdown]
# Impute Missing Values

# %%
df
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p      1.619462         x           g         o
# 1         p      1.873982         x           g         o
# 2         p      1.393432         x           g         o
# 3         p      1.412426         f           h         e
# 4         p      1.501699         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p     -1.054903         s           s         y
# 61065     p     -1.037808         f           s         y
# 61066     p     -1.037808         s           s         y
# 61067     p     -1.043506         f           s         y
# 61068     p     -1.056802         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e            c          w
# 1                        f               e            c          w
# 2                        f               e            c          w
# 3                        f               e            c          w
# 4                        f               e            c          w
# ...                    ...             ...          ...        ...
# 61064                    f               f            f          f
# 61065                    f               f            f          f
# 61066                    f               f            f          f
# 61067                    f               f            f          f
# 61068                    f               f            f          f
#
#        stem-height  stem-width stem-color has-ring ring-type habitat season
# 0         3.076705    0.492293          w        t         g       d      w
# 1         3.385311    0.601900          w        t         g       d      u
# 2         3.328931    0.557061          w        t         g       d      w
# 3         2.726555    0.381690          w        t         p       d      w
# 4         2.952075    0.503254          w        t         p       d      w
# ...            ...         ...        ...      ...       ...     ...    ...
# 61064    -0.786809   -0.590822          y        f         f       d      a
# 61065    -1.009362   -0.669539          y        f         f       d      a
# 61066    -0.807581   -0.575875          y        f         f       d      u
# 61067    -0.896602   -0.668543          y        f         f       d      u
# 61068    -0.988590   -0.667546          y        f         f       d      u
#
# [61069 rows x 16 columns]

# %%
# export clean data to CSV
df.to_csv('../Data/clean_data.csv', index=False)
